# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('monthdata.npz')

# %%
totals = data['totals']

# %%
counts = data['counts']

# %%
totals
# Out:
# array([[1809, 1482, 2159,  374,  606,  428,  442,   68,  956, 1429, 1349,
#         1846],
#        [ 121,   22,   46,   40,  683,  616, 2061,  834,  253,  276,   27,
#          224],
#        [ 896, 1232,  992, 1106, 1236, 1015, 1264, 1096, 1026, 2422, 1184,
#         1099],
#        [1491, 1473, 1452, 1595, 1001,  725,  734,  445,  845, 2185, 1305,
#         1835],
#        [ 930,  561,  533,  204,  546,  748,  662,  274,  785, 1620, 1293,
#          295],
#        [ 183,  982,  621,  471,  667,  671,  525, 1599,  433, 1176,  594,
#          627],
#        [ 363,  491,  729,  681,  346,  269,  399,  667,  663,  452,  497,
#          821],
#        [1682, 1304, 1616,  242,  516,  582,  328,  138,  784, 2034, 2402,
#         1520],
#        [ 220,   90,   28,  120,   98,  306,  154,  280,  488,  158,  176,
#          116]], dtype=uint64)

# %%
plt.plot(totals, counts)
# Out:
# [<matplotlib.lines.Line2D at 0x7f3b749b3630>,
#  <matplotlib.lines.Line2D at 0x7f3b749b3860>,
#  <matplotlib.lines.Line2D at 0x7f3b749b3a58>,
#  <matplotlib.lines.Line2D at 0x7f3b749b3c50>,
#  <matplotlib.lines.Line2D at 0x7f3b749b3e48>,
#  <matplotlib.lines.Line2D at 0x7f3b749bc080>,
#  <matplotlib.lines.Line2D at 0x7f3b749bc278>,
#  <matplotlib.lines.Line2D at 0x7f3b749bc470>,
#  <matplotlib.lines.Line2D at 0x7f3b749bc668>,
#  <matplotlib.lines.Line2D at 0x7f3b749bc860>,
#  <matplotlib.lines.Line2D at 0x7f3b749bca58>,
#  <matplotlib.lines.Line2D at 0x7f3b749bcc50>]

# %%
plt.show()

# %%
min_precip = np.argmin(totals.sum(axis = 1))

# %%
print("Row with the lowest precipitation:")
print(min_precip)
# Out:
# Row with the lowest precipitation:
# 8

# %%
total_precip_per_month = totals.sum(axis = 0)
total_precip_per_month
# Out:
# array([ 7695,  7637,  8176,  4833,  5699,  5360,  6569,  5401,  6233,
#        11752,  8827,  8383], dtype=uint64)

# %%
total_counts_per_month = counts.sum(axis = 0)
total_counts_per_month
# Out:
# array([277, 251, 278, 269, 267, 259, 263, 272, 259, 263, 255, 259], dtype=uint64)

# %%
avg_precip_per_month = total_precip_per_month / total_counts_per_month
avg_precip_per_month
# Out:
# array([ 27.77978339,  30.42629482,  29.41007194,  17.96654275,
#         21.34456929,  20.69498069,  24.97718631,  19.85661765,
#         24.06563707,  44.68441065,  34.61568627,  32.36679537])

# %%
print("Average precipitation in each month:")
print(avg_precip_per_month )
# Out:
# Average precipitation in each month:
# [ 27.77978339  30.42629482  29.41007194  17.96654275  21.34456929
#   20.69498069  24.97718631  19.85661765  24.06563707  44.68441065
#   34.61568627  32.36679537]

# %%
total_precip_per_city = totals.sum(axis = 1)
total_precip_per_city
# Out:
# array([12948,  5203, 14568, 15086,  8451,  8549,  6378, 13148,  2234], dtype=uint64)

# %%
total_counts_per_city = counts.sum(axis = 1)
total_counts_per_city
# Out:
# array([271, 363, 365, 364, 361, 361, 364, 360, 363], dtype=uint64)

# %%
avg_daily_precip_per_city = total_precip_per_city / total_counts_per_city
avg_daily_precip_per_city
# Out:
# array([ 47.77859779,  14.33333333,  39.91232877,  41.44505495,
#         23.4099723 ,  23.68144044,  17.52197802,  36.52222222,   6.15426997])

# %%
print("Average precipitation in each city:")
print(avg_daily_precip_per_city )
# Out:
# Average precipitation in each city:
# [ 47.77859779  14.33333333  39.91232877  41.44505495  23.4099723
#   23.68144044  17.52197802  36.52222222   6.15426997]

# %%
totals_reshaped = totals.reshape(totals.size // 12, 4, 3)

# %%
totals_reshaped2 = totals_reshaped.sum(axis = 2)

# %%
print("Quarterly precipitation totals:")
print(totals_reshaped2 )
# Out:
# Quarterly precipitation totals:
# [[5450 1408 1466 4624]
#  [ 189 1339 3148  527]
#  [3120 3357 3386 4705]
#  [4416 3321 2024 5325]
#  [2024 1498 1721 3208]
#  [1786 1809 2557 2397]
#  [1583 1296 1729 1770]
#  [4602 1340 1250 5956]
#  [ 338  524  922  450]]
